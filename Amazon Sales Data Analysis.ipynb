# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sales_data=pd.read_csv("C:\\Users\\reddy\\OneDrive\\Documents\\Amazon Sales data.csv")

# %%
sales_data.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
sales_data=sales_data[["Order ID","Order Date","Order Priority","Ship Date","Item Type","Region","Country","Sales Channel","Units Sold","Unit Price","Unit Cost","Total Revenue","Total Cost","Total Profit"]]

# %%
sales_data.columns
# Out:
# Index(['Order ID', 'Order Date', 'Order Priority', 'Ship Date', 'Item Type',
#        'Region', 'Country', 'Sales Channel', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
sales_data.shape
# Out:
# (100, 14)

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        100 non-null    int64
#  1   Order Date      100 non-null    object
#  2   Order Priority  100 non-null    object
#  3   Ship Date       100 non-null    object
#  4   Item Type       100 non-null    object
#  5   Region          100 non-null    object
#  6   Country         100 non-null    object
#  7   Sales Channel   100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'])

# %%
sales_data['Ship Date'] = pd.to_datetime(sales_data['Ship Date'])

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        100 non-null    int64
#  1   Order Date      100 non-null    datetime64[ns]
#  2   Order Priority  100 non-null    object
#  3   Ship Date       100 non-null    datetime64[ns]
#  4   Item Type       100 non-null    object
#  5   Region          100 non-null    object
#  6   Country         100 non-null    object
#  7   Sales Channel   100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 11.1+ KB

# %%
sales_data.isnull().sum()
# Out:
# Order ID          0
# Order Date        0
# Order Priority    0
# Ship Date         0
# Item Type         0
# Region            0
# Country           0
# Sales Channel     0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
sales_data.duplicated().sum()
# Out:
# 0

# %%
sales_data.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
sales_data.loc[:,["Total Revenue","Total Cost","Total Profit"]].iloc[:]
# Out:
#     Total Revenue  Total Cost  Total Profit
# 0      2533654.00  1582243.50     951410.50
# 1       576782.80   328376.44     248406.36
# 2      1158502.59   933903.84     224598.75
# 3        75591.66    56065.84      19525.82
# 4      3296425.02  2657347.52     639077.50
# ..            ...         ...           ...
# 95       97040.64    31825.92      65214.72
# 96       58471.11    43367.64      15103.47
# 97      228779.10   135031.05      93748.05
# 98      471336.91   326815.89     144521.02
# 99     3586605.09  2697132.18     889472.91
#
# [100 rows x 3 columns]

# %% [markdown]
# # Univariate Analysis

# %%
def numerical_univariate_analysis(numerical_data) :
     for col_name in numerical_data:
            print("*"*10, col_name,"*"*10)
            print(numerical_data[col_name].agg(['min','max','mean','median','std','skew','kurt']))
            print()

# %%
numerical_univariate_analysis(sales_data[['Units Sold']])
# Out:
# ********** Units Sold **********
# min        124.000000
# max       9925.000000
# mean      5128.710000
# median    5382.500000
# std       2794.484562
# skew        -0.099953
# kurt        -1.070528
# Name: Units Sold, dtype: float64

# %%
numerical_univariate_analysis(sales_data[['Unit Price']])
# Out:
# ********** Unit Price **********
# min         9.330000
# max       668.270000
# mean      276.761300
# median    179.880000
# std       235.592241
# skew        0.620751
# kurt       -1.152369
# Name: Unit Price, dtype: float64

# %%
numerical_univariate_analysis(sales_data[['Total Cost']])
# Out:
# ********** Total Cost **********
# min       3.612240e+03
# max       4.509794e+06
# mean      9.318057e+05
# median    3.635664e+05
# std       1.083938e+06
# skew      1.460512e+00
# kurt      1.529171e+00
# Name: Total Cost, dtype: float64

# %%
numerical_univariate_analysis(sales_data[['Total Revenue']])
# Out:
# ********** Total Revenue **********
# min       4.870260e+03
# max       5.997055e+06
# mean      1.373488e+06
# median    7.523144e+05
# std       1.460029e+06
# skew      1.277698e+00
# kurt      8.045392e-01
# Name: Total Revenue, dtype: float64

# %%
numerical_univariate_analysis(sales_data[['Total Profit']])
# Out:
# ********** Total Profit **********
# min       1.258020e+03
# max       1.719922e+06
# mean      4.416820e+05
# median    2.907680e+05
# std       4.385379e+05
# skew      1.238555e+00
# kurt      7.673982e-01
# Name: Total Profit, dtype: float64

# %%
sales_data.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
sales_data.head()
# Out:
#     Order ID Order Date Order Priority  Ship Date        Item Type  \
# 0  669165933  5/28/2010              H  6/27/2010        Baby Food
# 1  963881480  8/22/2012              C  9/15/2012           Cereal
# 2  341417157   5/2/2014              L   5/8/2014  Office Supplies
# 3  514321792  6/20/2014              C   7/5/2014           Fruits
# 4  115456712   2/1/2013              L   2/6/2013  Office Supplies
#
#                               Region                Country Sales Channel  \
# 0              Australia and Oceania                 Tuvalu       Offline
# 1  Central America and the Caribbean                Grenada        Online
# 2                             Europe                 Russia       Offline
# 3                 Sub-Saharan Africa  Sao Tome and Principe        Online
# 4                 Sub-Saharan Africa                 Rwanda       Offline
#
#    Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
sales_data['Region'].nunique()
# Out:
# 7

# %%
sales_data['Region'].unique()
# Out:
# array(['Australia and Oceania', 'Central America and the Caribbean',
#        'Europe', 'Sub-Saharan Africa', 'Asia',
#        'Middle East and North Africa', 'North America'], dtype=object)

# %%
sales_data['Region'].mode()
# Out:
# 0    Sub-Saharan Africa
# Name: Region, dtype: object

# %%
sales_data['Region'].value_counts()
# Out:
# Region
# Sub-Saharan Africa                   36
# Europe                               22
# Australia and Oceania                11
# Asia                                 11
# Middle East and North Africa         10
# Central America and the Caribbean     7
# North America                         3
# Name: count, dtype: int64

# %%
sales_data['Country'].nunique()
# Out:
# 76

# %%
sales_data['Country'].unique()
# Out:
# array(['Tuvalu', 'Grenada', 'Russia', 'Sao Tome and Principe', 'Rwanda',
#        'Solomon Islands', 'Angola', 'Burkina Faso',
#        'Republic of the Congo', 'Senegal', 'Kyrgyzstan', 'Cape Verde',
#        'Bangladesh', 'Honduras', 'Mongolia', 'Bulgaria', 'Sri Lanka',
#        'Cameroon', 'Turkmenistan', 'East Timor', 'Norway', 'Portugal',
#        'New Zealand', 'Moldova ', 'France', 'Kiribati', 'Mali',
#        'The Gambia', 'Switzerland', 'South Sudan', 'Australia', 'Myanmar',
#        'Djibouti', 'Costa Rica', 'Syria', 'Brunei', 'Niger', 'Azerbaijan',
#        'Slovakia', 'Comoros', 'Iceland', 'Macedonia', 'Mauritania',
#        'Albania', 'Lesotho', 'Saudi Arabia', 'Sierra Leone',
#        "Cote d'Ivoire", 'Fiji', 'Austria', 'United Kingdom', 'San Marino',
#        'Libya', 'Haiti', 'Gabon', 'Belize', 'Lithuania', 'Madagascar',
#        'Democratic Republic of the Congo', 'Pakistan', 'Mexico',
#        'Federated States of Micronesia', 'Laos', 'Monaco', 'Samoa ',
# ...

# %%
sales_data['Country'].mode()
# Out:
# 0    The Gambia
# Name: Country, dtype: object

# %%
sales_data['Country'].value_counts()
# Out:
# Country
# The Gambia               4
# Sierra Leone             3
# Sao Tome and Principe    3
# Mexico                   3
# Australia                3
#                         ..
# Comoros                  1
# Iceland                  1
# Macedonia                1
# Mauritania               1
# Mozambique               1
# Name: count, Length: 76, dtype: int64

# %%
sales_data['Sales Channel'].nunique()
# Out:
# 2

# %%
sales_data['Sales Channel'].unique()
# Out:
# array(['Offline', 'Online'], dtype=object)

# %%
sales_data['Sales Channel'].mode()
# Out:
# 0    Offline
# 1     Online
# Name: Sales Channel, dtype: object

# %%
sales_data['Sales Channel'].value_counts()
# Out:
# Sales Channel
# Offline    50
# Online     50
# Name: count, dtype: int64

# %%
sales_data['Item Type'].nunique()
# Out:
# 12

# %%
sales_data['Item Type'].unique()
# Out:
# array(['Baby Food', 'Cereal', 'Office Supplies', 'Fruits', 'Household',
#        'Vegetables', 'Personal Care', 'Clothes', 'Cosmetics', 'Beverages',
#        'Meat', 'Snacks'], dtype=object)

# %%
sales_data['Item Type'].value_counts()
# Out:
# Item Type
# Clothes            13
# Cosmetics          13
# Office Supplies    12
# Fruits             10
# Personal Care      10
# Household           9
# Beverages           8
# Baby Food           7
# Cereal              7
# Vegetables          6
# Snacks              3
# Meat                2
# Name: count, dtype: int64

# %%
sales_data['Order Priority'].nunique()
# Out:
# 4

# %%
sales_data['Order Priority'].unique()
# Out:
# array(['H', 'C', 'L', 'M'], dtype=object)

# %%
sales_data['Order Priority'].value_counts()
# Out:
# Order Priority
# H    30
# L    27
# C    22
# M    21
# Name: count, dtype: int64

# %%
sales_data.groupby('Item Type')['Order Priority'].count()
# Out:
# Item Type
# Baby Food           7
# Beverages           8
# Cereal              7
# Clothes            13
# Cosmetics          13
# Fruits             10
# Household           9
# Meat                2
# Office Supplies    12
# Personal Care      10
# Snacks              3
# Vegetables          6
# Name: Order Priority, dtype: int64

# %%
sales_data.groupby('Item Type')['Order Priority'].value_counts()
# Out:
# Item Type        Order Priority
# Baby Food        H                 3
#                  L                 2
#                  C                 1
#                  M                 1
# Beverages        C                 7
#                  H                 1
# Cereal           H                 5
#                  C                 1
#                  M                 1
# Clothes          C                 4
#                  H                 3
#                  L                 3
#                  M                 3
# Cosmetics        H                 8
#                  M                 3
#                  C                 1
#                  L                 1
# Fruits           L                 5
#                  H                 2
#                  M                 2
#                  C                 1
# Household        L                 5
#                  H                 2
#                  C                 1
# ...

# %%
sales_data.groupby('Region')['Country'].value_counts()
# Out:
# Region              Country
# Asia                Myanmar                  2
#                     Turkmenistan             2
#                     Bangladesh               1
#                     Brunei                   1
#                     Kyrgyzstan               1
#                                             ..
# Sub-Saharan Africa  Niger                    1
#                     Republic of the Congo    1
#                     Senegal                  1
#                     South Sudan              1
#                     Zambia                   1
# Name: count, Length: 76, dtype: int64

# %%
sales_data.groupby('Region')['Country'].count()
# Out:
# Region
# Asia                                 11
# Australia and Oceania                11
# Central America and the Caribbean     7
# Europe                               22
# Middle East and North Africa         10
# North America                         3
# Sub-Saharan Africa                   36
# Name: Country, dtype: int64

# %%
sales_data.groupby('Region')['Country'].value_counts().idxmax()
# Out:
# ('Sub-Saharan Africa', 'The Gambia')

# %%
sales_data.groupby('Region')[['Country','Item Type']].value_counts()
# Out:
# Region              Country     Item Type
# Asia                Bangladesh  Clothes            1
#                     Brunei      Office Supplies    1
#                     Kyrgyzstan  Vegetables         1
#                     Laos        Vegetables         1
#                     Malaysia    Fruits             1
#                                                   ..
# Sub-Saharan Africa  The Gambia  Baby Food          1
#                                 Cereal             1
#                                 Household          1
#                                 Meat               1
#                     Zambia      Snacks             1
# Name: count, Length: 97, dtype: int64

# %%
sales_data.groupby('Region')[['Country','Item Type']].count()
# Out:
#                                    Country  Item Type
# Region
# Asia                                    11         11
# Australia and Oceania                   11         11
# Central America and the Caribbean        7          7
# Europe                                  22         22
# Middle East and North Africa            10         10
# North America                            3          3
# Sub-Saharan Africa                      36         36

# %%
sales_data.groupby('Country')['Item Type'].count().idxmax()
# Out:
# 'The Gambia'

# %%
sales_data.groupby('Region')['Item Type'].max()
# Out:
# Region
# Asia                                      Vegetables
# Australia and Oceania                Office Supplies
# Central America and the Caribbean             Snacks
# Europe                                    Vegetables
# Middle East and North Africa         Office Supplies
# North America                          Personal Care
# Sub-Saharan Africa                        Vegetables
# Name: Item Type, dtype: object

# %%
import seaborn as sns
sns.set_style("darkgrid")
fi,axs=plt.subplots(1,2,figsize=(30,10))
sns.countplot(x="Region",data=sales_data,ax=axs[0])
sns.countplot(x="Item Type",data=sales_data,ax=axs[1])
for ax in axs:
    for label in ax.get_xticklabels():
        label.set_rotation(90)
plt.show()

# %%
import seaborn as sns
sns.set_style("darkgrid")
fi,axs=plt.subplots(1,2,figsize=(20,7))
sns.countplot(x="Order Priority",data=sales_data,ax=axs[0])
sns.countplot(x="Sales Channel",data=sales_data,ax=axs[1])
plt.show()

# %%
plt.figure(figsize=(20,8))
sns.countplot(x="Country",data=sales_data)
plt.xticks(rotation=90)
plt.show()

# %%
plt.hist(x='Total Profit', data=sales_data, bins=30, color='r', edgecolor ='black' )
#add labels plt.xlabel( 'X-Axis')
plt.ylabel( 'Y-Axis')
plt.title("Total Profit")
plt.grid (True,linestyle = '--', alpha = 0.5)
plt.show()

# %%
for col in df.columns:
    if df[col].dtype!="object":
        plt.boxplot(df[col])
        plt.xlabel(col)
        plt.show()

# %%
sales_data['Total Profit'].plot(kind='kde')
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
numerical_sales_data = sales_data.select_dtypes(include=[np.number])  
categorical_sales_data = sales_data.select_dtypes(exclude=[np.number])

# %%
numerical_sales_data.corr()
# Out:
#                Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID       1.000000   -0.222907   -0.190941  -0.213201      -0.314688
# Units Sold    -0.222907    1.000000   -0.070486  -0.092232       0.447784
# Unit Price    -0.190941   -0.070486    1.000000   0.987270       0.752360
# Unit Cost     -0.213201   -0.092232    0.987270   1.000000       0.715623
# Total Revenue -0.314688    0.447784    0.752360   0.715623       1.000000
# Total Cost    -0.328944    0.374746    0.787905   0.774895       0.983928
# Total Profit  -0.234638    0.564550    0.557365   0.467214       0.897327
#
#                Total Cost  Total Profit
# Order ID        -0.328944     -0.234638
# Units Sold       0.374746      0.564550
# Unit Price       0.787905      0.557365
# Unit Cost        0.774895      0.467214
# Total Revenue    0.983928      0.897327
# Total Cost       1.000000      0.804091
# Total Profit     0.804091      1.000000

# %%
pd.crosstab(sales_data['Item Type'], sales_data['Order Priority'], normalize='index')
# Out:
# Order Priority          C         H         L         M
# Item Type
# Baby Food        0.142857  0.428571  0.285714  0.142857
# Beverages        0.875000  0.125000  0.000000  0.000000
# Cereal           0.142857  0.714286  0.000000  0.142857
# Clothes          0.307692  0.230769  0.230769  0.230769
# Cosmetics        0.076923  0.615385  0.076923  0.230769
# Fruits           0.100000  0.200000  0.500000  0.200000
# Household        0.111111  0.222222  0.555556  0.111111
# Meat             0.000000  0.000000  0.500000  0.500000
# Office Supplies  0.166667  0.166667  0.250000  0.416667
# Personal Care    0.200000  0.100000  0.400000  0.300000
# Snacks           0.000000  0.000000  0.666667  0.333333
# Vegetables       0.333333  0.500000  0.166667  0.000000

# %%
pd.crosstab(sales_data['Item Type'], sales_data['Sales Channel'], normalize='index')
# Out:
# Sales Channel     Offline    Online
# Item Type
# Baby Food        0.428571  0.571429
# Beverages        0.750000  0.250000
# Cereal           0.428571  0.571429
# Clothes          0.461538  0.538462
# Cosmetics        0.538462  0.461538
# Fruits           0.200000  0.800000
# Household        0.888889  0.111111
# Meat             0.000000  1.000000
# Office Supplies  0.500000  0.500000
# Personal Care    0.700000  0.300000
# Snacks           0.000000  1.000000
# Vegetables       0.333333  0.666667

# %% [markdown]
# meat and snacks have highest online sales
#
# household has highest offline sales

# %%
pd.crosstab(sales_data['Region'], sales_data['Item Type'], normalize='index')
# Out:
# Item Type                          Baby Food  Beverages    Cereal   Clothes  \
# Region
# Asia                                0.000000   0.000000  0.000000  0.181818
# Australia and Oceania               0.181818   0.181818  0.090909  0.090909
# Central America and the Caribbean   0.000000   0.142857  0.142857  0.142857
# Europe                              0.181818   0.090909  0.000000  0.136364
# Middle East and North Africa        0.000000   0.000000  0.100000  0.200000
# North America                       0.000000   0.000000  0.000000  0.000000
# Sub-Saharan Africa                  0.027778   0.083333  0.111111  0.111111
#
# Item Type                          Cosmetics    Fruits  Household      Meat  \
# Region
# Asia                                0.090909  0.090909   0.181818  0.000000
# Australia and Oceania               0.090909  0.181818   0.000000  0.090909
# Central America and the Caribbean   0.142857  0.000000   0.142857  0.000000
# ...

# %%
g = sales_data.groupby('Region')

g['Total Profit'].agg(['min', 'max', 'mean'])
# Out:
#                                          min         max           mean
# Region
# Asia                                 7828.12  1367272.50  555804.170000
# Australia and Oceania                5270.67  1678540.98  429287.275455
# Central America and the Caribbean  122686.50  1487261.02  406701.121429
# Europe                               6841.38  1541705.29  503769.937727
# Middle East and North Africa         1258.02  1719922.04  576119.186000
# North America                      144521.02  1152486.42  485980.920000
# Sub-Saharan Africa                  14031.02  1254472.05  338422.538889

# %% [markdown]
# Middle East and North Africa and Asia has highest profits

# %%
g = sales_data.groupby('Item Type')

g['Total Profit'].agg(['min', 'max', 'mean'])
# Out:
#                        min         max          mean
# Item Type
# Baby Food        122029.78   951410.50  5.552348e+05
# Beverages         72975.60   147031.74  1.110059e+05
# Cereal            60418.38   766835.04  3.274919e+05
# Clothes           65214.72   727423.20  4.025642e+05
# Cosmetics        296448.35  1719922.04  1.119696e+06
# Fruits             1258.02    23150.46  1.204952e+04
# Household         46735.86  1487261.02  8.236229e+05
# Meat             272672.40   337937.60  3.053050e+05
# Office Supplies  119685.00  1046233.75  4.941320e+05
# Personal Care      6841.38   216919.36  1.220622e+05
# Snacks           122686.50   404010.78  2.506481e+05
# Vegetables         7828.12   510216.66  2.109699e+05

# %% [markdown]
# Cosmetics has high profit and fruits has low profit

# %%
g = sales_data.groupby('Item Type')

g['Unit Cost'].agg(['min', 'max', 'mean'])
# Out:
#                     min     max    mean
# Item Type
# Baby Food        159.42  159.42  159.42
# Beverages         31.79   31.79   31.79
# Cereal           117.11  117.11  117.11
# Clothes           35.84   35.84   35.84
# Cosmetics        263.33  263.33  263.33
# Fruits             6.92    6.92    6.92
# Household        502.54  502.54  502.54
# Meat             364.69  364.69  364.69
# Office Supplies  524.96  524.96  524.96
# Personal Care     56.67   56.67   56.67
# Snacks            97.44   97.44   97.44
# Vegetables        90.93   90.93   90.93

# %% [markdown]
# office supplies and household items have high cost and fruits have low cost

# %%
g = sales_data.groupby(['Region','Sales Channel'])

g['Total Profit'].agg(['min', 'max', 'mean'])
# Out:
#                                                        min         max  \
# Region                            Sales Channel
# Asia                              Offline         15103.47  1367272.50
#                                   Online           7828.12   846885.00
# Australia and Oceania             Offline         60418.38   951410.50
#                                   Online           5270.67  1678540.98
# Central America and the Caribbean Offline        127722.96  1487261.02
#                                   Online         122686.50   248406.36
# Europe                            Offline         72975.60  1505888.07
#                                   Online           6841.38  1541705.29
# Middle East and North Africa      Offline        449159.04  1719922.04
#                                   Online           1258.02  1257775.58
# North America                     Offline        144521.02  1152486.42
# ...

# %% [markdown]
# In North America sales are only in offline and in Central America and the Caribbean  also mostly in offline

# %%
g = sales_data.groupby(['Region','Item Type'])
g['Total Profit'].agg(['min', 'max', 'mean'])
# Out:
#                                                           min         max  \
# Region                            Item Type
# Asia                              Clothes           435499.20   606834.72
#                                   Cosmetics        1208744.24  1208744.24
#                                   Fruits             15103.47    15103.47
#                                   Household         634745.90  1367272.50
#                                   Office Supplies   632512.50   846885.00
#                                   Personal Care     122819.06   122819.06
#                                   Vegetables          7828.12   235601.16
# Australia and Oceania             Baby Food         285087.64   951410.50
#                                   Beverages         146875.14   147031.74
#                                   Cereal             60418.38    60418.38
#                                   Clothes           727423.20   727423.20
# ...

# %%
plt.scatter(x='Total Revenue',y='Total Profit',data=sales_data,marker='o',edgecolor ='blue',c='red',linewidth=1.5,alpha= 0.5)
plt.show()

# %% [markdown]
# The Total Profit is directly proportional to the total revenue where the revenue increases profit also increases and vice versa

# %%
sns.scatterplot(data=sales_data, x='Units Sold', y='Unit Cost')
plt.show()

# %% [markdown]
# unit cost is inveresly proportional to units sold that is when units sold is increasing then the cost will decrease and vice versa

# %%
fig, ax = plt.subplots(figsize=(20,8))

ax.set_title("Histogram Plot")
sns.barplot(data=sales_data, x='Region', y='Total Cost')

plt.show()

# %% [markdown]
# Cost of the items are more in Asia and North America and less in Sub-Saharan africa

# %%
fig, ax = plt.subplots(figsize=(30,15))

ax.set_title("Item Type Vs Order Priority",fontsize=25)
sns.countplot(data=sales_data, x='Item Type', hue='Order Priority', ax=ax)
plt.xticks(fontsize=20,color='black')
plt.yticks(fontsize=20,color='black')
plt.xlabel("Item Type",fontsize=25)
plt.ylabel("Count",fontsize=25)
plt.legend(fontsize=20)
plt.show()

# %% [markdown]
# The order priority of cosmetics is high
#
# The order priority of Beverages is Critical
#
# The order priority of Meat is low

# %%
# fig, ax = plt.subplots(figsize=(35,15))
plt.figure(figsize=(35,15))
ax.set_title("Item Type Vs Region",fontsize=30)
sns.countplot(data=sales_data, x='Item Type', hue='Region')
plt.legend(loc='upper right',fontsize=20)
plt.xticks(fontsize=20,color='black')
plt.yticks(fontsize=20,color='black')
plt.xlabel("Item Type",fontsize=25)
plt.ylabel("Count",fontsize=25)

plt.tight_layout()

plt.show()

# %% [markdown]
#  Europe and sub saharan africa have highest sales in items
#
#  Europe has highest sales in cosmetics
#
#  Central America and the Caribbean don't have any sales in baby food,office supplies,Fruits and Meat ,remaining items have almost equal sales
#
#  Sub Saharan Africa has highest sales in office supplies
#
#  Highest sales are happening in cosmetics,clothes and office supplies
#
# lowest sales in meat and snacks

# %%
sales_data.groupby('Order Priority')['Total Profit'].count().plot(kind='bar',color=['grey','blue','green','purple','brown'])
plt.ylabel('Total Profit')
plt.show()

# %% [markdown]
# Maximum profit has been generated by products having order priority 'H'
#
# while minimum profit has been obtained in case of 'C' priority product orders.

# %%
plt.figure(figsize=(12,5))
sales_data.groupby('Ship Date')['Total Profit'].sum().plot(kind='line',color='green')
plt.ylabel('Total Profit')
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# maximum profit has achieved in 2014

# %%
sales_data.groupby('Sales Channel')['Total Profit'].count().plot(kind='bar',color=['grey','blue'])
plt.ylabel('Total Profit')
plt.show()

# %% [markdown]
# Total profit generated in offline and online are equal

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='Country', y='Total Profit', data=sales_data, ci=None)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Pakisthan is the country where maximum revenue has been generated followed by Samoa.

# %%
pd.pivot_table(index='Order Date',values='Total Profit',data=sales_data,aggfunc='count').plot(kind='line',color='blue',legend=False)
plt.ylabel('Total Revenue')
plt.yticks(fontsize=12,color='green')
plt.xticks(fontsize=12)
plt.title('Revenue generated per year',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Revenue generated per year')

# %% [markdown]
# Here the total revenue are constant from 2012 to 2017

# %%
sns.heatmap(numerical_sales_data.corr(),annot=True,cmap='crest')
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above heatmap, we can infer that Total Cost is strongly related to Unit Price,Unit Cost ,Total Revenue and Total Profit.
#
# Units Sold and {Unit Price and Unit Cost} are completely independent.
#
# Number of units sold are independent of price charged per unit of a product and same with cost of a unit which is independent of units sold.
#
# Unit Cost, Unit Price and Total Cost are almost completely independent of Total Revenue.

# %%
print(sns.__version__)
# Out:
# 0.11.2

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.0
